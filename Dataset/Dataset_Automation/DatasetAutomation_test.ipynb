# %%
# !pip install -q torch transformers accelerate bitsandbytes pypdf
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 14.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 333.7/333.7 kB 33.2 MB/s eta 0:00:00

# %%
import os
os.environ["PYTORCH_ALLOC_CONF"] = "expandable_segments:True"

import csv
import os
import torch
from pathlib import Path
from pypdf import PdfReader
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

# %%
# !unzip Dataset_raw.zip
# Out:
# Archive:  Dataset_raw.zip
#    creating: consolidated_financial_statements/
#   inflating: consolidated_financial_statements/2021_Q1.pdf
#   inflating: consolidated_financial_statements/2021_Q2.pdf
#   inflating: consolidated_financial_statements/2021_Q3.pdf
#   inflating: consolidated_financial_statements/2021_Q4.pdf
#   inflating: consolidated_financial_statements/2022_Q1.pdf
#   inflating: consolidated_financial_statements/2022_Q2.pdf
#   inflating: consolidated_financial_statements/2022_Q3.pdf
#   inflating: consolidated_financial_statements/2022_Q4.pdf
#   inflating: consolidated_financial_statements/2023_Q1.pdf
#   inflating: consolidated_financial_statements/2023_Q2.pdf
#   inflating: consolidated_financial_statements/2023_Q3.pdf
#   inflating: consolidated_financial_statements/2023_Q4.pdf
#   inflating: consolidated_financial_statements/2024_Q1.pdf
#   inflating: consolidated_financial_statements/2024_Q2.pdf
#   inflating: consolidated_financial_statements/2024_Q3.pdf
#   inflating: consolidated_financial_statements/2024_Q4.pdf
#   inflating: consolidated_financial_statements/2025_Q1.pdf
#   inflating: consolidated_financial_statements/2025_Q2.pdf
#   inflating: consolidated_financial_statements/2025_Q3.pdf
#   inflating: consolidated_financial_statements/2025_Q4.pdf
#   inflating: consolidated_financial_statements/2026_Q1.pdf
#    creating: press_releases/
#   inflating: press_releases/2021_Q1.txt
#   inflating: press_releases/2021_Q2.txt
#   inflating: press_releases/2021_Q3.txt
#   inflating: press_releases/2021_Q4.txt
#   inflating: press_releases/2022_Q1.txt
#   inflating: press_releases/2022_Q2.txt
#   inflating: press_releases/2022_Q3.txt
#   inflating: press_releases/2022_Q4.txt
#   inflating: press_releases/2023_Q1.txt
#   inflating: press_releases/2023_Q2.txt
#   inflating: press_releases/2023_Q3.txt
#   inflating: press_releases/2023_Q4.txt
#   inflating: press_releases/2024_Q1.txt
#   inflating: press_releases/2024_Q2.txt
#   inflating: press_releases/2024_Q3.txt
#   inflating: press_releases/2024_Q4.txt
#   inflating: press_releases/2025_Q1.txt
#   inflating: press_releases/2025_Q2.txt
#   inflating: press_releases/2025_Q3.txt
#   inflating: press_releases/2025_Q4.txt
#   inflating: press_releases/2026_Q1.txt
#    creating: quarterly_filings/
#   inflating: quarterly_filings/2021_Q1.pdf
#   inflating: quarterly_filings/2021_Q2.pdf
#   inflating: quarterly_filings/2021_Q3.pdf
#   inflating: quarterly_filings/2021_Q4.pdf
#   inflating: quarterly_filings/2022_Q1.pdf
#   inflating: quarterly_filings/2022_Q2.pdf
#   inflating: quarterly_filings/2022_Q3.pdf
#   inflating: quarterly_filings/2022_Q4.pdf
#   inflating: quarterly_filings/2023_Q1.pdf
#   inflating: quarterly_filings/2023_Q2.pdf
#   inflating: quarterly_filings/2023_Q3.pdf
#   inflating: quarterly_filings/2023_Q4.pdf
#   inflating: quarterly_filings/2024_Q1.pdf
#   inflating: quarterly_filings/2024_Q2.pdf
#   inflating: quarterly_filings/2024_Q3.pdf
#   inflating: quarterly_filings/2024_Q4.pdf
#   inflating: quarterly_filings/2025_Q1.pdf
#   inflating: quarterly_filings/2025_Q2.pdf
#   inflating: quarterly_filings/2025_Q3.pdf
#   inflating: quarterly_filings/2025_Q4.pdf
#   inflating: quarterly_filings/2026_Q1.pdf

# %%
BASE_DIR = Path(".").resolve()
PRESS_DIR = BASE_DIR / "press_releases"
FIN_DIR = BASE_DIR / "consolidated_financial_statements"
FILING_DIR = BASE_DIR / "quarterly_filings"
OUTPUT_FILE = BASE_DIR / "mars_dataset.csv"

TOTAL_ROWS_PER_QUARTER = 150
BATCH_SIZE = 15
MAX_RETRIES = 3
START_ID = 1
hf_token = "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"
if not hf_token:
    raise ValueError("HF_TOKEN environment variable not set.")

# %%
# Qwen config (active)
MODEL_NAME = "Qwen/Qwen2.5-3B-Instruct"
tokenizer = AutoTokenizer.from_pretrained(
    MODEL_NAME,
    trust_remote_code=True,
    token=hf_token,
)

model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    torch_dtype=torch.float16,
    device_map="auto",
    low_cpu_mem_usage=True,
    trust_remote_code=True,
    token=hf_token,
)

model.eval()
# Out:
# config.json:   0%|          | 0.00/661 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/434 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# Qwen2ForCausalLM(
#   (model): Qwen2Model(
#     (embed_tokens): Embedding(151936, 2048)
#     (layers): ModuleList(
#       (0-35): 36 x Qwen2DecoderLayer(
#         (self_attn): Qwen2Attention(
#           (q_proj): Linear(in_features=2048, out_features=2048, bias=True)
#           (k_proj): Linear(in_features=2048, out_features=256, bias=True)
#           (v_proj): Linear(in_features=2048, out_features=256, bias=True)
#           (o_proj): Linear(in_features=2048, out_features=2048, bias=False)
#         )
#         (mlp): Qwen2MLP(
#           (gate_proj): Linear(in_features=2048, out_features=11008, bias=False)
#           (up_proj): Linear(in_features=2048, out_features=11008, bias=False)
#           (down_proj): Linear(in_features=11008, out_features=2048, bias=False)
#           (act_fn): SiLUActivation()
#         )
#         (input_layernorm): Qwen2RMSNorm((2048,), eps=1e-06)
#         (post_attention_layernorm): Qwen2RMSNorm((2048,), eps=1e-06)
#       )
#     )
#     (norm): Qwen2RMSNorm((2048,), eps=1e-06)
#     (rotary_emb): Qwen2RotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=2048, out_features=151936, bias=False)
# )

# %%
# Mistral config (archived - caused OOM on 14.56 GB GPU)
"""
MODEL_NAME = "mistralai/Mistral-7B-Instruct-v0.3"
tokenizer = AutoTokenizer.from_pretrained(
    MODEL_NAME,
    token=hf_token,
)

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
)

model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    quantization_config=bnb_config,
    device_map="auto",
    token=hf_token,
)

model.eval()
"""
# Out:
# '\nMODEL_NAME = "mistralai/Mistral-7B-Instruct-v0.3"\ntokenizer = AutoTokenizer.from_pretrained(\n    MODEL_NAME,\n    token=hf_token,\n)\n\nbnb_config = BitsAndBytesConfig(\n    load_in_4bit=True,\n    bnb_4bit_compute_dtype=torch.float16,\n    bnb_4bit_use_double_quant=True,\n    bnb_4bit_quant_type="nf4",\n)\n\nmodel = AutoModelForCausalLM.from_pretrained(\n    MODEL_NAME,\n    quantization_config=bnb_config,\n    device_map="auto",\n    token=hf_token,\n)\n\nmodel.eval()\n'

# %%
FIELDNAMES = [
    "case_id",
    "quarter",
    "department",
    "decision_title",
    "decision_archetype",
    "trigger",
    "decision_description",
    "options_considered",
    "chosen_option",
    "reasoning_summary",
    "quantitative_signals",
    "risk_level",
    "cross_dept_impact",
    "expected_profit_impact",
    "profit_confidence",
    "profit_impact_pathway",
    "outcome_status",
    "outcome_summary",
    "decision_tags",
    "finance_agent_conf",
    "r&d_agent_conf",
    "ops_agent_conf",
    "legal_agent_conf",
    "conflicting_perspectives",
    "master_agent_decision",
    "master_agent_confidence",
]

def extract_pdf_text(pdf_path):
    reader = PdfReader(str(pdf_path))
    text = ""
    for page in reader.pages:
        text += page.extract_text() or ""
    return text

def chunk_text(text, max_chars=6000):
    return text[:max_chars]

def validate_batch(rows, expected_start):
    titles = set()
    expected = expected_start

    for row in rows:
        try:
            cid = int(row["case_id"])
        except Exception:
            return False

        if cid != expected:
            return False

        if row["decision_title"] in titles:
            return False

        titles.add(row["decision_title"])
        expected += 1

    return True

def generate(prompt):
    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=1200,
            do_sample=False,
            pad_token_id=tokenizer.eos_token_id,
        )

    decoded = tokenizer.decode(outputs[0], skip_special_tokens=True)
    result = decoded[len(prompt):].strip()

    # Free GPU memory after each generation
    del inputs, outputs
    torch.cuda.empty_cache()

    return result

def build_prompt(quarter, press_text, fin_text, filing_text, start_id, batch_size):
    example_csv = """case_id,quarter,department,decision_title,decision_archetype,trigger,decision_description,options_considered,chosen_option,reasoning_summary,quantitative_signals,risk_level,cross_dept_impact,expected_profit_impact,profit_confidence,profit_impact_pathway,outcome_status,outcome_summary,decision_tags,finance_agent_conf,r&d_agent_conf,ops_agent_conf,legal_agent_conf,conflicting_perspectives,master_agent_decision,master_agent_confidence
1,Q1-2024,Finance,Optimize Services Pricing Mix,Margin Optimization,"Services revenue reached record high","Evaluate pricing tiers to protect margin expansion.","Maintain; Increase premium tier; Discount entry tier","Increase premium tier","Premium tier improves ARPU without eroding base demand.","Services:$23.1B; GM:72.8%",Medium,"R&D","+0.2%",0.91,"Higher ARPU -> Margin Expansion",Pending,"Pilot pricing test launched.","services;pricing;margin",0.98,0.85,0.75,0.80,"R&D concerned about feature gating.",Approve premium tier test,0.95"""

    return f"""
You are generating structured enterprise decision records.

Below is an example of the EXACT CSV format required:

{example_csv}

Now generate EXACTLY {batch_size} new rows.

STRICT RULES:
- Output ONLY CSV rows.
- No explanation.
- No markdown.
- No blank lines.
- Sequential numeric case_id starting from {start_id}.
- No duplicate decision_title.
- Departments allowed: Finance, Operations, R&D, Legal.
- Use ONLY financial numbers explicitly present in the documents.
- All decisions must be materially different.
- Follow the exact column order shown above.

Quarter:
{quarter}

PRESS RELEASE:
{press_text}

FINANCIAL DATA:
{fin_text}

FILING:
{filing_text}

Return only CSV rows.
"""

# %%
def main():
    all_rows = []
    current_id = START_ID
    quarters = sorted([f.stem for f in PRESS_DIR.glob("*.txt")])
    print("Quarters found:", quarters)

    for quarter in quarters:
        print(f"\nProcessing {quarter}")
        press_path = PRESS_DIR / f"{quarter}.txt"
        fin_path = FIN_DIR / f"{quarter}.pdf"
        filing_path = FILING_DIR / f"{quarter}.pdf"

        if not fin_path.exists() or not filing_path.exists():
            print("Missing PDFs for", quarter)
            continue

        press_text = press_path.read_text()[:1500]
        fin_text = chunk_text(extract_pdf_text(fin_path), max_chars=2000)
        filing_text = chunk_text(extract_pdf_text(filing_path), max_chars=2000)

        rows_generated = 0
        retries = 0

        while rows_generated < TOTAL_ROWS_PER_QUARTER:
            batch_start_id = current_id
            batch_size = min(BATCH_SIZE, TOTAL_ROWS_PER_QUARTER - rows_generated)
            prompt = build_prompt(
                quarter, press_text, fin_text, filing_text,
                batch_start_id, batch_size
            )
            print(f"\nGenerating batch starting {batch_start_id}")
            input_token_count = len(tokenizer.encode(prompt))
            print("Input token count:", input_token_count)
            output = generate(prompt)
            lines = [line for line in output.splitlines() if line.strip() != ""]

            if lines and lines[0].startswith("case_id"):
                lines = lines[1:]

            reader = csv.DictReader(lines, fieldnames=FIELDNAMES)
            rows = list(reader)
            print("Parsed rows:")

            for r in rows:
                print(r)

            valid_rows = []

            for row in rows:
                try:
                    cid = int(row["case_id"])
                except:
                    continue
                if cid == current_id:
                    valid_rows.append(row)
                    current_id += 1
                    rows_generated += 1

            if valid_rows:
                retries = 0
                print(f"Accepted {len(valid_rows)} rows")
                all_rows.extend(valid_rows)
                with open(OUTPUT_FILE, "w", newline="") as f:
                    writer = csv.DictWriter(f, fieldnames=FIELDNAMES)
                    writer.writeheader()
                    writer.writerows(all_rows)
                print(f"Checkpoint saved ({len(all_rows)} total rows)")

            else:
                retries += 1
                print(f"No valid rows extracted. Retry {retries}/{MAX_RETRIES}...")
                if retries >= MAX_RETRIES:
                    print("Max retries hit, skipping batch.")
                    current_id += batch_size
                    rows_generated += batch_size
                    retries = 0

        print(f"Completed quarter {quarter}")

    print("\nAll quarters complete.")
    print(f"Final dataset size: {len(all_rows)} rows")

main()
# Out:
# Quarters found: ['2021_Q1', '2021_Q2', '2021_Q3', '2021_Q4', '2022_Q1', '2022_Q2', '2022_Q3', '2022_Q4', '2023_Q1', '2023_Q2', '2023_Q3', '2023_Q4', '2024_Q1', '2024_Q2', '2024_Q3', '2024_Q4', '2025_Q1', '2025_Q2', '2025_Q3', '2025_Q4', '2026_Q1']
#
# Processing 2021_Q1
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating batch starting 1
# Input token count: 2201
# Parsed rows:
# {'case_id': '2', 'quarter': '2021_Q1', 'department': 'Finance', 'decision_title': 'Maximize Cash Flow Management', 'decision_archetype': 'Margin Optimization', 'trigger': 'Cash reserves are at historical low', 'decision_description': 'Evaluate strategies to optimize cash flow management.', 'options_considered': 'Maintain; Increase investment in inventory; Reduce capital expenditures', 'chosen_option': 'Increase investment in inventory', 'reasoning_summary': 'Increase investment in inventory', 'quantitative_signals': 'Inventory optimization reduces working capital needs.', 'risk_level': 'Inventory:$10B; Working Capital:$5B', 'cross_dept_impact': 'Low', 'expected_profit_impact': 'Internal', 'profit_confidence': '+0.5%', 'profit_impact_pathway': '0.92', 'outcome_status': 'Improved liquidity', 'outcome_summary': 'Pending', 'decision_tags': 'Investment in inventory increases to boost liquidity.', 'finance_agent_conf': 'inventory;cashflow;liquidity', 'r&d_agent_conf': '0.95', 'ops_agent_conf': '0.88', 'legal_agent_conf': '0.90', 'conflicting_perspectives': '0.85', 'master_agent_decision': 'Ops and Legal concerned about potential delays in inventory turnover.', 'master_agent_confidence': 'Approve inventory investment', None: ['0.94']}
# {'case_id': '3', 'quarter': '2021_Q1', 'department': 'Operations', 'decision_title': 'Reduce Supply Chain Risk', 'decision_archetype': 'Operational Efficiency', 'trigger': 'Supply chain disruptions increase', 'decision_description': 'Assess supply chain resilience and identify areas for improvement.', 'options_considered': 'Maintain; Strengthen supplier relationships; Enhance logistics flexibility', 'chosen_option': 'Strengthen supplier relationships', 'reasoning_summary': 'Strengthen supplier relationships', 'quantitative_signals': 'Supplier relationships enhance reliability and reduce variability.', 'risk_level': 'Supplier Relationships:$15B', 'cross_dept_impact': 'High', 'expected_profit_impact': 'External', 'profit_confidence': '+0.3%', 'profit_impact_pathway': '0.90', 'outcome_status': 'Lower risk exposure', 'outcome_summary': 'Pending', 'decision_tags': 'Supplier network strengthened to mitigate future disruptions.', 'finance_agent_conf': 'supplychain;resilience', 'r&d_agent_conf': '0.93', 'ops_agent_conf': '0.89', 'legal_agent_conf': '0.92', 'conflicting_perspectives': '0.87', 'master_agent_decision': 'Legal concerns about contract terms.', 'master_agent_confidence': 'Approve supplier strengthening', None: ['0.91']}
# {'case_id': '4', 'quarter': '2021_Q1', 'department': 'R&D', 'decision_title': 'Accelerate Product Development', 'decision_archetype': 'Technology Innovation', 'trigger': 'Product backlog exceeds capacity', 'decision_description': 'Prioritize development of high-demand products.', 'options_considered': 'Maintain; Prioritize existing projects; Initiate new initiatives', 'chosen_option': 'Initiate new initiatives', 'reasoning_summary': 'Initiate new initiatives', 'quantitative_signals': 'New initiatives drive innovation and market leadership.', 'risk_level': 'New Initiatives:$10B', 'cross_dept_impact': 'Medium', 'expected_profit_impact': 'Internal', 'profit_confidence': '+0.4%', 'profit_impact_pathway': '0.91', 'outcome_status': 'Increased market share', 'outcome_summary': 'Pending', 'decision_tags': 'New product launches accelerate market penetration.', 'finance_agent_conf': 'productdevelopment;innovation', 'r&d_agent_conf': '0.96', 'ops_agent_conf': '0.90', 'legal_agent_conf': '0.94', 'conflicting_perspectives': '0.92', 'master_agent_decision': 'Finance and Ops worried about resource allocation.', 'master_agent_confidence': 'Approve new initiatives', None: ['0.95']}
# {'case_id': '5', 'quarter': '2021_Q1', 'department': 'Legal', 'decision_title': 'Enhance Compliance', 'decision_archetype': 'Regulatory Compliance', 'trigger': 'Regulatory scrutiny intensifies', 'decision_description': 'Review compliance policies and procedures.', 'options_considered': 'Maintain; Update policies; Implement monitoring systems', 'chosen_option': 'Update policies', 'reasoning_summary': 'Update policies', 'quantitative_signals': 'Updated policies ensure regulatory adherence.', 'risk_level': 'Policy Updates:$5B', 'cross_dept_impact': 'Medium', 'expected_profit_impact': 'External', 'profit_confidence': '+0.2%', 'profit_impact_pathway': '0.90', 'outcome_status': 'Reduced legal risks', 'outcome_summary': 'Pending', 'decision_tags': 'Compliance policies updated to address new regulations.', 'finance_agent_conf': 'compliance;regulation', 'r&d_agent_conf': '0.92', 'ops_agent_conf': '0.88', 'legal_agent_conf': '0.91', 'conflicting_perspectives': '0.90', 'master_agent_decision': 'Finance and Ops concerned about additional costs.', 'master_agent_confidence': 'Approve policy updates', None: ['0.93']}
# {'case_id': '6', 'quarter': '2021_Q1', 'department': 'Finance', 'decision_title': 'Optimize Revenue Recognition', 'decision_archetype': 'Revenue Management', 'trigger': 'Revenue recognition practices lag behind industry standards', 'decision_description': 'Evaluate and improve revenue recognition processes.', 'options_considered': 'Maintain; Improve internal controls; Enhance reporting accuracy', 'chosen_option': 'Improve internal controls', 'reasoning_summary': 'Improve internal controls', 'quantitative_signals': 'Improved controls lead to accurate and timely reporting.', 'risk_level': 'Internal Controls:$8B', 'cross_dept_impact': 'Medium', 'expected_profit_impact': 'Internal', 'profit_confidence': '+0.3%', 'profit_impact_pathway': '0.91', 'outcome_status': 'Enhanced reporting', 'outcome_summary': 'Pending', 'decision_tags': 'Revenue recognition processes improved to align with industry best practices.', 'finance_agent_conf': 'revenue;reporting', 'r&d_agent_conf': '0.94', 'ops_agent_conf': '0.90', 'legal_agent_conf': '0.92', 'conflicting_perspectives': '0.91', 'master_agent_decision': 'Legal and Ops concerned about potential audit findings.', 'master_agent_confidence': 'Approve internal controls', None: ['0.93']}
# {'case_id': '7', 'quarter': '2021_Q1', 'department': 'Operations', 'decision_title': 'Streamline Supply Chain Processes', 'decision_archetype': 'Operational Efficiency', 'trigger': 'Supply chain inefficiencies persist', 'decision_description': 'Identify and implement process improvements.', 'options_considered': 'Maintain; Streamline existing processes; Introduce automation', 'chosen_option': 'Introduce automation', 'reasoning_summary': 'Introduce automation', 'quantitative_signals': 'Automation enhances efficiency and reduces variability.', 'risk_level': 'Process Automation:$5B', 'cross_dept_impact': 'Medium', 'expected_profit_impact': 'Internal', 'profit_confidence': '+0.4%', 'profit_impact_pathway': '0.90', 'outcome_status': 'Increased productivity', 'outcome_summary': 'Pending', 'decision_tags': 'Supply chain processes streamlined to improve efficiency.', 'finance_agent_conf': 'supplychain;efficiency', 'r&d_agent_conf': '0.91', 'ops_agent_conf': '0.92', 'legal_agent_conf': '0.93', 'conflicting_perspectives': '0.90', 'master_agent_decision': 'Finance and Ops concerned about initial implementation costs.', 'master_agent_confidence': 'Approve automation', None: ['0.92']}
# {'case_id': '8', 'quarter': '2021_Q1', 'department': 'R&D', 'decision_title': 'Accelerate Research and Development', 'decision_archetype': 'Technology Innovation', 'trigger': 'Research funding remains constrained', 'decision_description': 'Prioritize high-potential projects.', 'options_considered': 'Maintain; Prioritize existing projects; Initiate new initiatives', 'chosen_option': 'Initiate new initiatives', 'reasoning_summary': 'Initiate new initiatives', 'quantitative_signals': 'New initiatives drive innovation and market leadership.', 'risk_level': 'New Initiatives:$10B', 'cross_dept_impact': 'Medium', 'expected_profit_impact': 'Internal', 'profit_confidence': '+0.4%', 'profit_impact_pathway': '0.91', 'outcome_status': 'Increased market share', 'outcome_summary': 'Pending', 'decision_tags': 'Research projects initiated to accelerate innovation.', 'finance_agent_conf': 'research;innovation', 'r&d_agent_conf': '0.95', 'ops_agent_conf': '0.92', 'legal_agent_conf': '0.94', 'conflicting_perspectives': '0.93', 'master_agent_decision': 'Finance and Ops worried about resource allocation.', 'master_agent_confidence': 'Approve new initiatives', None: ['0.94']}
# {'case_id': '9', 'quarter': '2021_Q1', 'department': 'Finance', 'decision_title': 'Optimize Cost Structure', 'decision_archetype': 'Cost Reduction', 'trigger': 'Cost-cutting measures are necessary', 'decision_description': 'Evaluate and implement cost-saving initiatives.', 'options_considered': 'Maintain; Reduce discretionary spending; Optimize operations', 'chosen_option': 'Reduce discretionary spending', 'reasoning_summary': 'Reduce discretionary spending', 'quantitative_signals': 'Reducing discretionary spending leads to cost savings.', 'risk_level': 'Discretionary Spending:$6B', 'cross_dept_impact': 'Medium', 'expected_profit_impact': 'Internal', 'profit_confidence': '+0.3%', 'profit_impact_pathway': '0.91', 'outcome_status': 'Cost reduction achieved', 'outcome_summary': 'Pending', 'decision_tags': 'Discretionary spending reduced to focus on core operations.', 'finance_agent_conf': '', 'r&d_agent_conf': None, 'ops_agent_conf': None, 'legal_agent_conf': None, 'conflicting_perspectives': None, 'master_agent_decision': None, 'master_agent_confidence': None}
# No valid rows extracted. Retry 1/3...
#
# Generating batch starting 1
# Input token count: 2201
# Parsed rows:
# {'case_id': '2', 'quarter': '2021_Q1', 'department': 'Finance', 'decision_title': 'Maximize Cash Flow Management', 'decision_archetype': 'Margin Optimization', 'trigger': 'Cash reserves are at historical low', 'decision_description': 'Evaluate strategies to optimize cash flow management.', 'options_considered': 'Maintain; Increase investment in inventory; Reduce capital expenditures', 'chosen_option': 'Increase investment in inventory', 'reasoning_summary': 'Increase investment in inventory', 'quantitative_signals': 'Inventory optimization reduces working capital needs.', 'risk_level': 'Inventory:$10B; Working Capital:$5B', 'cross_dept_impact': 'Low', 'expected_profit_impact': 'Internal', 'profit_confidence': '+0.5%', 'profit_impact_pathway': '0.92', 'outcome_status': 'Improved liquidity', 'outcome_summary': 'Pending', 'decision_tags': 'Investment in inventory increases to boost liquidity.', 'finance_agent_conf': 'inventory;cashflow;liquidity', 'r&d_agent_conf': '0.95', 'ops_agent_conf': '0.88', 'legal_agent_conf': '0.90', 'conflicting_perspectives': '0.85', 'master_agent_decision': 'Ops and Legal concerned about potential delays in inventory turnover.', 'master_agent_confidence': 'Approve inventory investment', None: ['0.94']}
# {'case_id': '3', 'quarter': '2021_Q1', 'department': 'Operations', 'decision_title': 'Reduce Supply Chain Risk', 'decision_archetype': 'Operational Efficiency', 'trigger': 'Supply chain disruptions increase', 'decision_description': 'Assess supply chain resilience and identify areas for improvement.', 'options_considered': 'Maintain; Strengthen supplier relationships; Enhance logistics flexibility', 'chosen_option': 'Strengthen supplier relationships', 'reasoning_summary': 'Strengthen supplier relationships', 'quantitative_signals': 'Supplier relationships enhance reliability and reduce variability.', 'risk_level': 'Supplier Relationships:$15B', 'cross_dept_impact': 'High', 'expected_profit_impact': 'External', 'profit_confidence': '+0.3%', 'profit_impact_pathway': '0.90', 'outcome_status': 'Lower risk exposure', 'outcome_summary': 'Pending', 'decision_tags': 'Supplier network strengthened to mitigate future disruptions.', 'finance_agent_conf': 'supplychain;resilience', 'r&d_agent_conf': '0.93', 'ops_agent_conf': '0.89', 'legal_agent_conf': '0.92', 'conflicting_perspectives': '0.87', 'master_agent_decision': 'Legal concerns about contract terms.', 'master_agent_confidence': 'Approve supplier strengthening', None: ['0.91']}
# {'case_id': '4', 'quarter': '2021_Q1', 'department': 'R&D', 'decision_title': 'Accelerate Product Development', 'decision_archetype': 'Technology Innovation', 'trigger': 'Product backlog exceeds capacity', 'decision_description': 'Prioritize development of high-demand products.', 'options_considered': 'Maintain; Prioritize existing projects; Initiate new initiatives', 'chosen_option': 'Initiate new initiatives', 'reasoning_summary': 'Initiate new initiatives', 'quantitative_signals': 'New initiatives drive innovation and market leadership.', 'risk_level': 'New Initiatives:$10B', 'cross_dept_impact': 'Medium', 'expected_profit_impact': 'Internal', 'profit_confidence': '+0.4%', 'profit_impact_pathway': '0.91', 'outcome_status': 'Increased market share', 'outcome_summary': 'Pending', 'decision_tags': 'New product launches accelerate market penetration.', 'finance_agent_conf': 'productdevelopment;innovation', 'r&d_agent_conf': '0.96', 'ops_agent_conf': '0.90', 'legal_agent_conf': '0.94', 'conflicting_perspectives': '0.92', 'master_agent_decision': 'Finance and Ops worried about resource allocation.', 'master_agent_confidence': 'Approve new initiatives', None: ['0.95']}
# {'case_id': '5', 'quarter': '2021_Q1', 'department': 'Legal', 'decision_title': 'Enhance Compliance', 'decision_archetype': 'Regulatory Compliance', 'trigger': 'Regulatory scrutiny intensifies', 'decision_description': 'Review compliance policies and procedures.', 'options_considered': 'Maintain; Update policies; Implement monitoring systems', 'chosen_option': 'Update policies', 'reasoning_summary': 'Update policies', 'quantitative_signals': 'Updated policies ensure regulatory adherence.', 'risk_level': 'Policy Updates:$5B', 'cross_dept_impact': 'Medium', 'expected_profit_impact': 'External', 'profit_confidence': '+0.2%', 'profit_impact_pathway': '0.90', 'outcome_status': 'Reduced legal risks', 'outcome_summary': 'Pending', 'decision_tags': 'Compliance policies updated to address new regulations.', 'finance_agent_conf': 'compliance;regulation', 'r&d_agent_conf': '0.92', 'ops_agent_conf': '0.88', 'legal_agent_conf': '0.91', 'conflicting_perspectives': '0.90', 'master_agent_decision': 'Finance and Ops concerned about additional costs.', 'master_agent_confidence': 'Approve policy updates', None: ['0.93']}
# {'case_id': '6', 'quarter': '2021_Q1', 'department': 'Finance', 'decision_title': 'Optimize Revenue Recognition', 'decision_archetype': 'Revenue Management', 'trigger': 'Revenue recognition practices lag behind industry standards', 'decision_description': 'Evaluate and improve revenue recognition processes.', 'options_considered': 'Maintain; Improve internal controls; Enhance reporting accuracy', 'chosen_option': 'Improve internal controls', 'reasoning_summary': 'Improve internal controls', 'quantitative_signals': 'Improved controls lead to accurate and timely reporting.', 'risk_level': 'Internal Controls:$8B', 'cross_dept_impact': 'Medium', 'expected_profit_impact': 'Internal', 'profit_confidence': '+0.3%', 'profit_impact_pathway': '0.91', 'outcome_status': 'Enhanced reporting', 'outcome_summary': 'Pending', 'decision_tags': 'Revenue recognition processes improved to align with industry best practices.', 'finance_agent_conf': 'revenue;reporting', 'r&d_agent_conf': '0.94', 'ops_agent_conf': '0.90', 'legal_agent_conf': '0.92', 'conflicting_perspectives': '0.91', 'master_agent_decision': 'Legal and Ops concerned about potential audit findings.', 'master_agent_confidence': 'Approve internal controls', None: ['0.93']}
# {'case_id': '7', 'quarter': '2021_Q1', 'department': 'Operations', 'decision_title': 'Streamline Supply Chain Processes', 'decision_archetype': 'Operational Efficiency', 'trigger': 'Supply chain inefficiencies persist', 'decision_description': 'Identify and implement process improvements.', 'options_considered': 'Maintain; Streamline existing processes; Introduce automation', 'chosen_option': 'Introduce automation', 'reasoning_summary': 'Introduce automation', 'quantitative_signals': 'Automation enhances efficiency and reduces variability.', 'risk_level': 'Process Automation:$5B', 'cross_dept_impact': 'Medium', 'expected_profit_impact': 'Internal', 'profit_confidence': '+0.4%', 'profit_impact_pathway': '0.90', 'outcome_status': 'Increased productivity', 'outcome_summary': 'Pending', 'decision_tags': 'Supply chain processes streamlined to improve efficiency.', 'finance_agent_conf': 'supplychain;efficiency', 'r&d_agent_conf': '0.91', 'ops_agent_conf': '0.92', 'legal_agent_conf': '0.93', 'conflicting_perspectives': '0.90', 'master_agent_decision': 'Finance and Ops concerned about initial implementation costs.', 'master_agent_confidence': 'Approve automation', None: ['0.92']}
# {'case_id': '8', 'quarter': '2021_Q1', 'department': 'R&D', 'decision_title': 'Accelerate Research and Development', 'decision_archetype': 'Technology Innovation', 'trigger': 'Research funding remains constrained', 'decision_description': 'Prioritize high-potential projects.', 'options_considered': 'Maintain; Prioritize existing projects; Initiate new initiatives', 'chosen_option': 'Initiate new initiatives', 'reasoning_summary': 'Initiate new initiatives', 'quantitative_signals': 'New initiatives drive innovation and market leadership.', 'risk_level': 'New Initiatives:$10B', 'cross_dept_impact': 'Medium', 'expected_profit_impact': 'Internal', 'profit_confidence': '+0.4%', 'profit_impact_pathway': '0.91', 'outcome_status': 'Increased market share', 'outcome_summary': 'Pending', 'decision_tags': 'Research projects initiated to accelerate innovation.', 'finance_agent_conf': 'research;innovation', 'r&d_agent_conf': '0.95', 'ops_agent_conf': '0.92', 'legal_agent_conf': '0.94', 'conflicting_perspectives': '0.93', 'master_agent_decision': 'Finance and Ops worried about resource allocation.', 'master_agent_confidence': 'Approve new initiatives', None: ['0.94']}
# {'case_id': '9', 'quarter': '2021_Q1', 'department': 'Finance', 'decision_title': 'Optimize Cost Structure', 'decision_archetype': 'Cost Reduction', 'trigger': 'Cost-cutting measures are necessary', 'decision_description': 'Evaluate and implement cost-saving initiatives.', 'options_considered': 'Maintain; Reduce discretionary spending; Optimize operations', 'chosen_option': 'Reduce discretionary spending', 'reasoning_summary': 'Reduce discretionary spending', 'quantitative_signals': 'Reducing discretionary spending leads to cost savings.', 'risk_level': 'Discretionary Spending:$6B', 'cross_dept_impact': 'Medium', 'expected_profit_impact': 'Internal', 'profit_confidence': '+0.3%', 'profit_impact_pathway': '0.91', 'outcome_status': 'Cost reduction achieved', 'outcome_summary': 'Pending', 'decision_tags': 'Discretionary spending reduced to focus on core operations.', 'finance_agent_conf': '', 'r&d_agent_conf': None, 'ops_agent_conf': None, 'legal_agent_conf': None, 'conflicting_perspectives': None, 'master_agent_decision': None, 'master_agent_confidence': None}
# No valid rows extracted. Retry 2/3...
#
# Generating batch starting 1
# Input token count: 2201
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2096/103168785.py in <cell line: 0>()
#      81     print(f"Final dataset size: {len(all_rows)} rows")
#      82
# ---> 83 main()
#
# /tmp/ipykernel_2096/103168785.py in main()
#      32             input_token_count = len(tokenizer.encode(prompt))
#      33             print("Input token count:", input_token_count)
# ---> 34             output = generate(prompt)
#      35             lines = [line for line in output.splitlines() if line.strip() != ""]
#      36
#
# /tmp/ipykernel_2096/1078392700.py in generate(prompt)
#      63
#      64     with torch.no_grad():
# ---> 65         outputs = model.generate(
#      66             **inputs,
#      67             max_new_tokens=1200,
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     122         # pyrefly: ignore [bad-context-manager]
#     123         with ctx_factory():
# --> 124             return func(*args, **kwargs)
#     125
#     126     return decorate_context
#
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, custom_generate, **kwargs)
#    2667
#    2668         # 9. Call generation mode
# -> 2669         result = decoding_method(
#    2670             self,
#    2671             input_ids,
#
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py in _sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    2872                 model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
#    2873                 with self._optimize_model_for_decode():
# -> 2874                     outputs = model_forward(**model_inputs, return_dict=True)
#    2875             prefill_consumed = True
#    2876             model_kwargs = self._update_model_kwargs_for_generation(
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py in wrapper(self, *args, **kwargs)
#     833         if return_dict_passed is not None:
#     834             return_dict = return_dict_passed
# --> 835         output = func(self, *args, **kwargs)
#     836         if not return_dict and not isinstance(output, tuple):
#     837             output = output.to_tuple()
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/qwen2/modeling_qwen2.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, cache_position, logits_to_keep, **kwargs)
#     473         "Hey, are you conscious? Can you talk to me?\nI'm not conscious, but I can talk to you."
#     474         ```"""
# --> 475         outputs: BaseModelOutputWithPast = self.model(
#     476             input_ids=input_ids,
#     477             attention_mask=attention_mask,
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py in wrapper(self, *args, **kwargs)
#    1000                         outputs = func(self, *args, **kwargs)
#    1001                 else:
# -> 1002                     outputs = func(self, *args, **kwargs)
#    1003             except TypeError as original_exception:
#    1004                 # If we get a TypeError, it's possible that the model is not receiving the recordable kwargs correctly.
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/qwen2/modeling_qwen2.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, cache_position, **kwargs)
#     408
#     409         for decoder_layer in self.layers[: self.config.num_hidden_layers]:
# --> 410             hidden_states = decoder_layer(
#     411                 hidden_states,
#     412                 attention_mask=causal_mask_mapping[decoder_layer.attention_type],
#
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_layers.py in __call__(self, *args, **kwargs)
#      91
#      92             return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 93         return super().__call__(*args, **kwargs)
#      94
#      95
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/qwen2/modeling_qwen2.py in forward(self, hidden_states, attention_mask, position_ids, past_key_values, use_cache, cache_position, position_embeddings, **kwargs)
#     296         hidden_states = self.input_layernorm(hidden_states)
#     297         # Self Attention
# --> 298         hidden_states, _ = self.self_attn(
#     299             hidden_states=hidden_states,
#     300             attention_mask=attention_mask,
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/qwen2/modeling_qwen2.py in forward(self, hidden_states, position_embeddings, attention_mask, past_key_values, cache_position, **kwargs)
#     218         query_states = self.q_proj(hidden_states).view(hidden_shape).transpose(1, 2)
#     219         key_states = self.k_proj(hidden_states).view(hidden_shape).transpose(1, 2)
# --> 220         value_states = self.v_proj(hidden_states).view(hidden_shape).transpose(1, 2)
#     221
#     222         cos, sin = position_embeddings
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     132         Runs the forward pass.
#     133         """
# --> 134         return F.linear(input, self.weight, self.bias)
#     135
#     136     def extra_repr(self) -> str:
#
# KeyboardInterrupt:
